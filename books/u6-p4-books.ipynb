# %% [markdown]
# Создано на основе https://github.com/zygmuntz/goodbooks-10k/

# %%
import numpy as np
import pandas as pd
import scipy.sparse as sparse
from lightfm import LightFM
from lightfm.cross_validation import random_train_test_split
from lightfm.evaluation import precision_at_k, recall_at_k
 
try:
    ratings
except NameError:
    ratings = pd.read_csv('data/ratings.csv.zip', low_memory=False)
    
try:
    books
except NameError:
    books = pd.read_csv('data/books.csv.zip', low_memory=False)

try:
    tags
except NameError:
    tags = pd.read_csv('data/tags_cleaned.csv.zip', low_memory=False)
    
try:
    book_tags
except NameError:
    book_tags = pd.read_csv('data/book_tags.csv.zip')

# %%
mapper = dict(zip(books.goodreads_book_id,books.book_id))
book_tags = book_tags[book_tags.tag_id.isin(tags.tag_id)]
book_tags['id'] = book_tags.goodreads_book_id.apply(lambda x: mapper[x])

# %%
ratings_coo = sparse.coo_matrix((ratings.rating,(ratings.user_id,ratings.book_id)))
feature_ratings  = sparse.coo_matrix(([1]*len(book_tags),(book_tags.id,book_tags.tag_id)))
# print(ratings_coo)
# print(feature_ratings)

# %%
#Разбиваем наш датасет на обучающую и тестовую выборки
train,test = random_train_test_split(ratings_coo, test_percentage=0.2, random_state=None)

# %%
#число потоков нашего процессора
NUM_THREADS = 8 

#число параметров вектора 
NUM_COMPONENTS = 30 

#число эпох обучения
NUM_EPOCHS = 10 

#Создаём модель
model = LightFM(learning_rate=0.05, loss='warp', no_components=NUM_COMPONENTS)
 
#Обучаем модель
model = model.fit(train, epochs=NUM_EPOCHS, num_threads=NUM_THREADS,item_features =feature_ratings)

# %%
#Тестируем нашу модель
prec_score = precision_at_k(
                     model,
                     test,
                     num_threads=NUM_THREADS,
                     k=10,
                     item_features=feature_ratings).mean()
 
recall_at_k = recall_at_k(model,
                     test,
                     num_threads=NUM_THREADS,
                     k=10,
                     item_features=feature_ratings).mean()

print(recall_at_k,prec_score)

# %%
# Достаём эбмеддинги

item_biases, item_embeddings = model.get_item_representations(features=feature_ratings)

# %%
item_embeddings

# %%
import pickle
with open('item_embeddings.pickle', 'wb') as file:
    pickle.dump(item_embeddings, file, protocol=pickle.HIGHEST_PROTOCOL)

# %%
import nmslib
 
#Создаём наш граф для поиска
nms_idx = nmslib.init(method='hnsw', space='cosinesimil')
 
#Начинаем добавлять наши книги в граф
nms_idx.addDataPointBatch(item_embeddings)
nms_idx.createIndex(print_progress=True)

# %%
#Вспомогательная функция для поиска по графу
def nearest_books_nms(book_id, index, n=10):
    nn = index.knnQuery(item_embeddings[book_id], k=n)
    return nn

# %%
books[books.original_title.str.find('1984')>=0].head(2)
# Out:
#      book_id  goodreads_book_id  best_book_id  work_id  books_count  \
# 845      846               5472          5472  2966408           51
#
#           isbn        isbn13                              authors  \
# 845  151010269  9.780151e+12  George Orwell, Christopher Hitchens
#
#      original_publication_year       original_title  ... ratings_count  \
# 845                     1950.0   Animal Farm & 1984  ...        116197
#
#     work_ratings_count  work_text_reviews_count  ratings_1  ratings_2  \
# 845             118761                     1293       1212       3276
#
#      ratings_3  ratings_4  ratings_5  \
# 845      16511      40583      57179
#
#                                              image_url  \
# 845  https://images.gr-assets.com/books/1327959366m...
#
#                                        small_image_url
# 845  https://images.gr-assets.com/books/1327959366s...
#
# [1 rows x 23 columns]

# %%
id = 846
nbm = nearest_books_nms(id,nms_idx)[0]
books[books.book_id.isin(nbm)]
# Out:
#       book_id  goodreads_book_id  best_book_id   work_id  books_count  \
# 13         14               7613          7613   2207778          896
# 47         48               4381          4381   1272463          507
# 54         55               5129          5129   3204877          515
# 288       289              76620         76620   1357456          193
# 374       375               1852          1852   3252320         1384
# 845       846               5472          5472   2966408           51
# 2489     2490             721012        721012  18197624          302
# 4591     4592              90192         90192   1483780          636
# 6154     6155             989313        989313  19248724            7
#
#             isbn        isbn13  \
# 13     452284244  9.780452e+12
# 47     307347974  9.780307e+12
# 54      60929871  9.780061e+12
# 288   038039586X  9.780380e+12
# 374    439227143  9.780439e+12
# 845    151010269  9.780151e+12
# 2489  014043769X  9.780140e+12
# 4591   393924769  9.780394e+12
# 6154  1593080212  9.781593e+12
#
#                                                 authors  \
# 13                                        George Orwell
# 47                                         Ray Bradbury
# 54                                        Aldous Huxley
# 288                                       Richard Adams
# 374                                         Jack London
# 845                 George Orwell, Christopher Hitchens
# 2489  Geoffrey Crayon, Washington Irving, William L....
# 4591              Nathaniel Hawthorne, Robert S. Levine
# 6154                    Joseph Conrad, A. Michael Matin
#
#       original_publication_year                            original_title  \
# 13                       1945.0                Animal Farm: A Fairy Story
# 47                       1953.0                            Fahrenheit 451
# 54                       1932.0                           Brave New World
# 288                      1972.0                            Watership Down
# 374                      1903.0                      The Call of the Wild
# 845                      1950.0                        Animal Farm & 1984
# 2489                     1819.0  The Sketch Book of Geoffrey Crayon, Gent
# 4591                     1851.0             The House of the Seven Gables
# 6154                     1899.0                                       NaN
#
#       ... ratings_count work_ratings_count  work_text_reviews_count  \
# 13    ...       1881700            1982987                    35472
# 47    ...        570498            1176240                    30694
# 54    ...       1022601            1079135                    20095
# 288   ...        292426             308373                    10399
# 374   ...        223932             248795                     6770
# 845   ...        116197             118761                     1293
# 2489  ...         42952              45496                      437
# 4591  ...         23797              28715                     1651
# 6154  ...         18873              19392                      192
#
#       ratings_1  ratings_2  ratings_3  ratings_4  ratings_5  \
# 13        66854     135147     433432     698642     648912
# 47        28366      64289     238242     426292     419051
# 54        26367      60328     219895     389379     383166
# 288        9158      15767      52906     102093     128449
# 374        6366      16636      62853      90382      72558
# 845        1212       3276      16511      40583      57179
# 2489        449       2192      11813      16501      14541
# 4591       1373       3640       9601       8899       5202
# 6154       1061       1793       4477       5759       6302
#
#                                               image_url  \
# 13    https://images.gr-assets.com/books/1424037542m...
# 47    https://images.gr-assets.com/books/1351643740m...
# 54    https://images.gr-assets.com/books/1487389574m...
# 288   https://images.gr-assets.com/books/1405136931m...
# 374   https://images.gr-assets.com/books/1452291694m...
# 845   https://images.gr-assets.com/books/1327959366m...
# 2489  https://images.gr-assets.com/books/1309285607m...
# 4591  https://s.gr-assets.com/assets/nophoto/book/11...
# 6154  https://images.gr-assets.com/books/1328851164m...
#
#                                         small_image_url
# 13    https://images.gr-assets.com/books/1424037542s...
# 47    https://images.gr-assets.com/books/1351643740s...
# 54    https://images.gr-assets.com/books/1487389574s...
# 288   https://images.gr-assets.com/books/1405136931s...
# 374   https://images.gr-assets.com/books/1452291694s...
# 845   https://images.gr-assets.com/books/1327959366s...
# 2489  https://images.gr-assets.com/books/1309285607s...
# 4591  https://s.gr-assets.com/assets/nophoto/book/50...
# 6154  https://images.gr-assets.com/books/1328851164s...
#
# [9 rows x 23 columns]

# %%
books[books.original_title.str.find('The Silence of the Lambs')>=0].head(2)
# Out:
#      book_id  goodreads_book_id  best_book_id  work_id  books_count      isbn  \
# 208      209              23807         23807    22533          187  99446782
#
#            isbn13        authors  original_publication_year  \
# 208  9.780099e+12  Thomas Harris                     1988.0
#
#                original_title  ... ratings_count work_ratings_count  \
# 208  The Silence of the Lambs  ...        351107             366112
#
#      work_text_reviews_count  ratings_1  ratings_2  ratings_3  ratings_4  \
# 208                     3866      10268      12845      55427     123652
#
#      ratings_5                                          image_url  \
# 208     163920  https://images.gr-assets.com/books/1390426249m...
#
#                                        small_image_url
# 208  https://images.gr-assets.com/books/1390426249s...
#
# [1 rows x 23 columns]

# %%
id = 209
nbm = nearest_books_nms(id,nms_idx)[0]
books[books.book_id.isin(nbm)]
# Out:
#       book_id  goodreads_book_id  best_book_id  work_id  books_count  \
# 208       209              23807         23807    22533          187
# 430       431              28877         28877   925503          191
# 767       768              21686         21686  1234227          134
# 981       982              40024         40024  2266643           70
# 1484     1485              21704         21704      434           93
# 1801     1802              32418         32418  2992500          132
# 3405     3406              18402         18402  2164481           77
# 4421     4422              32416         32416    46673           94
# 5312     5313              21727         21727   593515           46
#
#             isbn        isbn13         authors  original_publication_year  \
# 208     99446782  9.780099e+12   Thomas Harris                     1988.0
# 430    525945563  9.780526e+12   Thomas Harris                     1981.0
# 767   038073186X  9.780381e+12   Dennis Lehane                     2003.0
# 981    812976142  9.780813e+12      Caleb Carr                     1994.0
# 1484   446698873  9.780447e+12    James Ellroy                     1987.0
# 1801    99297701  9.780099e+12   Thomas Harris                     1999.0
# 3405  034549038X  9.780345e+12   Matthew Pearl                     2003.0
# 4421   385339410  9.780385e+12   Thomas Harris                     2006.0
# 5312   307279952  9.780307e+12  Scott B. Smith                     1993.0
#
#                 original_title  ... ratings_count work_ratings_count  \
# 208   The Silence of the Lambs  ...        351107             366112
# 430                 Red Dragon  ...        194013             205433
# 767             Shutter Island  ...        113718             124032
# 981               The Alienist  ...         96981             100908
# 1484          The Black Dahlia  ...         61412              65404
# 1801                  Hannibal  ...         57569              63555
# 3405            The Dante Club  ...         31035              33728
# 4421           Hannibal Rising  ...         22767              25973
# 5312             A Simple Plan  ...         18628              19650
#
#       work_text_reviews_count  ratings_1  ratings_2  ratings_3  ratings_4  \
# 208                      3866      10268      12845      55427     123652
# 430                      3309       3012       7790      43235      80662
# 767                      6990       1636       4727      22089      49875
# 981                      4026       1798       4571      18715      37572
# 1484                     1944       1999       4999      17641      23340
# 1801                     2098       2166       5811      17220      20844
# 3405                     2206       1822       4320      11905      10640
# 4421                     1317       1468       3733       8087       7174
# 5312                      986        478       1086       4239       7690
#
#       ratings_5                                          image_url  \
# 208      163920  https://images.gr-assets.com/books/1390426249m...
# 430       70734  https://s.gr-assets.com/assets/nophoto/book/11...
# 767       45705  https://images.gr-assets.com/books/1329269081m...
# 981       38252  https://s.gr-assets.com/assets/nophoto/book/11...
# 1484      17425  https://images.gr-assets.com/books/1387048173m...
# 1801      17514  https://images.gr-assets.com/books/1327356556m...
# 3405       5041  https://s.gr-assets.com/assets/nophoto/book/11...
# 4421       5511  https://images.gr-assets.com/books/1394208690m...
# 5312       6157  https://s.gr-assets.com/assets/nophoto/book/11...
#
#                                         small_image_url
# 208   https://images.gr-assets.com/books/1390426249s...
# 430   https://s.gr-assets.com/assets/nophoto/book/50...
# 767   https://images.gr-assets.com/books/1329269081s...
# 981   https://s.gr-assets.com/assets/nophoto/book/50...
# 1484  https://images.gr-assets.com/books/1387048173s...
# 1801  https://images.gr-assets.com/books/1327356556s...
# 3405  https://s.gr-assets.com/assets/nophoto/book/50...
# 4421  https://images.gr-assets.com/books/1394208690s...
# 5312  https://s.gr-assets.com/assets/nophoto/book/50...
#
# [9 rows x 23 columns]
